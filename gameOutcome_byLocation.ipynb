# %%
# Import dependencies
import pandas as pd

#Include all SportsReference for now
from sportsreference.nfl.boxscore import Boxscore
from sportsreference.nfl.schedule import Schedule
from sportsreference.nfl.teams import Teams

# %%
# Get abbreviations
abbreviations = Teams()
for team in abbreviations:
    print(team.name, team.abbreviation)  # Prints the team's name and abbreviation
# Out:
# Baltimore Ravens RAV
# New England Patriots NWE
# Kansas City Chiefs KAN
# Tampa Bay Buccaneers TAM
# Los Angeles Rams RAM
# Philadelphia Eagles PHI
# Seattle Seahawks SEA
# Dallas Cowboys DAL
# Houston Texans HTX
# Carolina Panthers CAR
# San Francisco 49ers SFO
# Green Bay Packers GNB
# New Orleans Saints NOR
# Indianapolis Colts CLT
# Minnesota Vikings MIN
# Jacksonville Jaguars JAX
# Oakland Raiders RAI
# Los Angeles Chargers SDG
# Atlanta Falcons ATL
# Arizona Cardinals CRD
# Pittsburgh Steelers PIT
# Tennessee Titans OTI
# New York Giants NYG
# Detroit Lions DET
# Cleveland Browns CLE
# Buffalo Bills BUF
# Denver Broncos DEN
# Chicago Bears CHI
# Cincinnati Bengals CIN
# Washington Redskins WAS
# New York Jets NYJ
# Miami Dolphins MIA

# %%
# Make into a list
# Get all team abbreviations in an array
abbrList = []
for team in abbreviations: 
    abbrList.append(team.abbreviation)
print(abbrList)
# Out:
# ['RAV', 'NWE', 'KAN', 'TAM', 'RAM', 'PHI', 'SEA', 'DAL', 'HTX', 'CAR', 'SFO', 'GNB', 'NOR', 'CLT', 'MIN', 'JAX', 'RAI', 'SDG', 'ATL', 'CRD', 'PIT', 'OTI', 'NYG', 'DET', 'CLE', 'BUF', 'DEN', 'CHI', 'CIN', 'WAS', 'NYJ', 'MIA']

# %%
# Loop attempt one. (Getting info as list)
for abbr in abbrList: 
    print(abbr)
    team_schedule = Schedule(abbr)
    print(f"Number games: {len(team_schedule)}")
    for game in team_schedule:
        print(game.location, game.result)
# Out:
# RAV
# Number games: 16
# Away Win
# Home Win
# Away Loss
# Home Loss
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# NWE
# Number games: 16
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# KAN
# Number games: 16
# Away Win
# Away Win
# Home Win
# Away Win
# Home Loss
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# TAM
# Number games: 16
# Home Loss
# Away Win
# Home Loss
# Away Win
# Away Loss
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# RAM
# Number games: 16
# Away Win
# Home Win
# Away Win
# Home Loss
# Away Loss
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# PHI
# Number games: 16
# Home Win
# Away Loss
# Home Loss
# Away Win
# Home Win
# Away Win
# Away Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# SEA
# Number games: 16
# Home Win
# Away Win
# Home Loss
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# DAL
# Number games: 16
# Home Win
# Away Win
# Home Win
# Away Loss
# Home Loss
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# HTX
# Number games: 16
# Away Loss
# Home Win
# Away Win
# Home Loss
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# CAR
# Number games: 16
# Home Loss
# Home Loss
# Away Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# SFO
# Number games: 16
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# GNB
# Number games: 16
# Away Win
# Home Win
# Home Win
# Home Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# NOR
# Number games: 16
# Home Win
# Away Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# CLT
# Number games: 16
# Away Loss
# Away Win
# Home Win
# Home Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# MIN
# Number games: 16
# Home Win
# Away Loss
# Home Win
# Away Loss
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# JAX
# Number games: 16
# Home Loss
# Away Loss
# Home Win
# Away Win
# Away Loss
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# RAI
# Number games: 16
# Home Win
# Home Loss
# Away Loss
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# SDG
# Number games: 16
# Home Win
# Away Loss
# Home Loss
# Away Win
# Home Loss
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# ATL
# Number games: 16
# Away Loss
# Home Win
# Away Loss
# Home Loss
# Away Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# CRD
# Number games: 16
# Home Win
# Away Loss
# Home Loss
# Home Loss
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Away Win
# PIT
# Number games: 16
# Away Loss
# Home Loss
# Away Loss
# Home Win
# Home Loss
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# OTI
# Number games: 16
# Away Win
# Home Loss
# Away Loss
# Away Win
# Home Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# NYG
# Number games: 16
# Away Loss
# Home Loss
# Away Win
# Home Win
# Home Loss
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# DET
# Number games: 16
# Away Win
# Home Win
# Away Win
# Home Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# CLE
# Number games: 16
# Home Loss
# Away Win
# Home Loss
# Away Win
# Away Loss
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# BUF
# Number games: 16
# Away Win
# Away Win
# Home Win
# Home Loss
# Away Win
# Home Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# DEN
# Number games: 16
# Away Loss
# Home Loss
# Away Loss
# Home Loss
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# CHI
# Number games: 16
# Home Loss
# Away Win
# Away Win
# Home Win
# Away Loss
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# CIN
# Number games: 16
# Away Loss
# Home Loss
# Away Loss
# Away Loss
# Home Loss
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# WAS
# Number games: 16
# Away Loss
# Home Loss
# Home Loss
# Away Loss
# Home Loss
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Home Win
# Away Win
# NYJ
# Number games: 16
# Home Loss
# Home Loss
# Away Loss
# Away Loss
# Home Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# MIA
# Number games: 16
# Home Loss
# Home Loss
# Away Loss
# Home Loss
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Home Win
# Away Win
# Away Win
# Home Win
# Away Win

# %%
# Refined loop, get ID and percentage of home wins
for abbr in abbrList: 
    print(abbr)
    team_schedule = Schedule(abbr)
    homeCount = 0
    homeWin = 0
    awayCount = 0
    awayWin = 0
    for game in team_schedule:
        if game.location == "Home":
            homeCount += 1
            if game.result == "Win":
                homeWin += 1 
        elif game.location =="Away":
            awayCount += 1
            if game.result =="Win":
                awayWin += 1
    print(f"Home win rate: {(homeWin/homeCount)*100}%")
    print(f"Away win rate: {(awayWin/awayCount)*100}%")
# Out:
# RAV
# Home win rate: 87.5%
# Away win rate: 87.5%
# NWE
# Home win rate: 100.0%
# Away win rate: 100.0%
# KAN
# Home win rate: 87.5%
# Away win rate: 100.0%
# TAM
# Home win rate: 75.0%
# Away win rate: 87.5%
# RAM
# Home win rate: 87.5%
# Away win rate: 87.5%
# PHI
# Home win rate: 87.5%
# Away win rate: 87.5%
# SEA
# Home win rate: 87.5%
# Away win rate: 100.0%
# DAL
# Home win rate: 87.5%
# Away win rate: 87.5%
# HTX
# Home win rate: 87.5%
# Away win rate: 87.5%
# CAR
# Home win rate: 75.0%
# Away win rate: 100.0%
# SFO
# Home win rate: 100.0%
# Away win rate: 100.0%
# GNB
# Home win rate: 87.5%
# Away win rate: 100.0%
# NOR
# Home win rate: 100.0%
# Away win rate: 87.5%
# CLT
# Home win rate: 87.5%
# Away win rate: 87.5%
# MIN
# Home win rate: 100.0%
# Away win rate: 75.0%
# JAX
# Home win rate: 87.5%
# Away win rate: 75.0%
# RAI
# Home win rate: 87.5%
# Away win rate: 87.5%
# SDG
# Home win rate: 75.0%
# Away win rate: 87.5%
# ATL
# Home win rate: 87.5%
# Away win rate: 62.5%
# CRD
# Home win rate: 75.0%
# Away win rate: 87.5%
# PIT
# Home win rate: 75.0%
# Away win rate: 75.0%
# OTI

# %%
## Next step: make this into a chart/dataframe? JSON file? How do we want to export this?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f09970475d17> in <module>
#       8
#       9 for abbr in abbrList:
# ---> 10     gameDict[team].push(abbr),
#      11     team_schedule = Schedule(abbr)
#      12     for game in team_schedule:
#
# KeyError: <sportsreference.nfl.teams.Team object at 0x000001C13AD64EF0>
